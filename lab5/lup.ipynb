# %%
from LUP import LinearSystem
from SquaredMatrix import SquaredMatrix
from Vector import Vector

# %%
A = SquaredMatrix([[2, 3, 1],
     [4, 7, 3],
     [6, 2, 5]])
B = SquaredMatrix([[0, 3, 5],
     [4, 1, 3],
     [2, 23, -1]])

c = Vector([1, 3, 5])
d = Vector([3, 2, -1])

# %%
A*B
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 A*B
#
# File d:\University\third_course\AppliedAlgorithms\lab5\SquaredMatrix.py:54, in SquaredMatrix.__mul__(self, other)
#      52     new_row = []
#      53     for j in range(other.size):
# ---> 54         new_row.append(self.rows[i] * other.rows[j])
#      55     result_rows.append(Vector(new_row))
#      57 return SquaredMatrix(result_rows)
#
# File d:\University\third_course\AppliedAlgorithms\lab5\Vector.py:54, in Vector.__mul__(self, other)
#      52 # Scalar multiplication of vectors
#      53 elif isinstance(other, Vector):
# ---> 54     self.size_error(self, other)
#      55     return sum(a * b for a, b in zip(self.elements, other.elements))
#      56 else:
#
# TypeError: Vector.size_error() takes 2 positional arguments but 3 were given

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
A = [
    [2, -1, 3, 0, 4, -2],
    [1, 2, -1, 4, 0, 3],
    [3, 0, 2, -1, 1, 5],
    [0, 4, -2, 1, 3, -1],
    [1, -2, 0, 5, 4, 2],
    [2, 3, 1, -1, 0, 4]
]

b = [5, 6, 8, 7, 4, 10]

linear_system = LinearSystem(A, b)
solution = linear_system.solve()
print("Solution:", solution)
# Out:
# Solution: [-0.007915567282321826, 1.7902374670184693, 1.4129287598944582, 0.2981530343007916, 1.0831134564643798, 0.882585751978892]
